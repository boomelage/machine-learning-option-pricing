# %%
import os
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

file = os.path.join(Path(),[f for f in os.listdir(Path()) if f.endswith('.pkl')][0])
models = joblib.load(file)

# %%
retraining_dates = [d for d in model.keys()]
for d in retraining_dates:
    m = models[d]
    print()
    print(d)
    print(m['test_data'].iloc[:,-4:].describe())
    print()
# Out:
# 2023-08-09
#        observed_price  outofsample_target  outofsample_prediction  \
# count   434689.000000       434689.000000           434689.000000
# mean      1557.725800         1557.725800             1577.205815
# std        919.198017          919.198017              912.427928
# min         41.159813           41.159813                0.000000
# 25%       1114.788312         1114.788312             1115.030454
# 50%       1363.688955         1363.688955             1501.699419
# 75%       2488.197847         2488.197847             2481.223528
# max       2938.135999         2938.135999             2867.389490
#
#        outofsample_error
# count      434689.000000
# mean           19.480016
# std            65.556079
# min          -135.917406
# 25%           -24.325996
# 50%            -0.830556
# 75%            59.558266
# max           679.758995
#
#
# 2023-08-10
#        observed_price  outofsample_target  outofsample_prediction  \
# ...
